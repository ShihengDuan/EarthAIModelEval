# %%
import glob
import os
import numpy as np
from pcmdi_metrics.graphics import download_archived_results
from pcmdi_metrics.graphics import normalize_by_median
from pcmdi_metrics.graphics import TaylorDiagram
from matplotlib import pyplot as plt
from pcmdi_metrics.graphics import Metrics
import pcmdi_metrics
from pcmdi_metrics.graphics import parallel_coordinate_plot

# %%
print(pcmdi_metrics.__version__)
# Out:
# 3.9.1

# %%
json_list1 = sorted(glob.glob("/global/cfs/cdirs/m4581/lee1043/work/cdat/pmp/ACE_evaluation/mean_climate/output/cmip6/amip/v20251020/*.json"))
for json_file in json_list1:
    print(json_file.split('/')[-1])
# Out:
# pr_2.5x2.5_regrid2_metrics_v20251020.json
# ta-200_2.5x2.5_regrid2_metrics_v20251020.json
# ta-850_2.5x2.5_regrid2_metrics_v20251020.json
# ua-200_2.5x2.5_regrid2_metrics_v20251020.json
# ua-850_2.5x2.5_regrid2_metrics_v20251020.json
# va-200_2.5x2.5_regrid2_metrics_v20251020.json
# va-850_2.5x2.5_regrid2_metrics_v20251020.json
# zg-500_2.5x2.5_regrid2_metrics_v20251020.json

# %%
json_list2 = sorted(glob.glob("/global/cfs/cdirs/m4581/lee1043/work/cdat/pmp/ACE_evaluation/mean_climate/output/cmip6/amip/v20250915/*.json"))
for json_file in json_list2:
    print(json_file.split('/')[-1])
# Out:
# pr_2.5x2.5_regrid2_metrics_v20250915.json
# psl_2.5x2.5_regrid2_metrics_v20250915.json
# ta-200_2.5x2.5_regrid2_metrics_v20250915.json
# ta-850_2.5x2.5_regrid2_metrics_v20250915.json
# va-200_2.5x2.5_regrid2_metrics_v20250915.json
# va-850_2.5x2.5_regrid2_metrics_v20250915.json

# %%
json_list = json_list1[:]+json_list2[1:2]

# %%
library = Metrics(json_list)
# library2 = Metrics(json_list2)
# library3 = Metrics(json_list3[3:5])
# library = library.merge(library2)
# library = library.merge(library3)

# %%
json_dir_test = './demo_output/climatology-ACE/'
json_list_test = sorted(glob.glob(os.path.join(json_dir_test, '*.json')))
for json_file in json_list_test:
    print(json_file.split('/')[-1])
# Out:
# pr_2.5x2.5_regrid2_metrics_climatology-ACE.json
# psl_2.5x2.5_regrid2_metrics_climatology-ACE.json
# ta-200_2.5x2.5_regrid2_metrics_climatology-ACE.json
# ta-500_2.5x2.5_regrid2_metrics_climatology-ACE.json
# ta-850_2.5x2.5_regrid2_metrics_climatology-ACE.json
# ua-200_2.5x2.5_regrid2_metrics_climatology-ACE.json
# ua-850_2.5x2.5_regrid2_metrics_climatology-ACE.json
# va-200_2.5x2.5_regrid2_metrics_climatology-ACE.json
# va-850_2.5x2.5_regrid2_metrics_climatology-ACE.json

# %%
json_list_test_NGCM_evap = sorted(glob.glob(os.path.join('./demo_output/climatology-NGCM-evap/', '*.json')))
for json_file in json_list_test_NGCM_evap:
    print(json_file.split('/')[-1])
# Out:
# pr_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# ta-200_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# ta-500_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# ta-850_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# ua-200_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# ua-850_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# va-200_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# va-850_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# zg-200_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# zg-500_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json
# zg-850_2.5x2.5_regrid2_metrics_climatology-NGCM-evap.json

# %%
json_list_test_NGCM = sorted(glob.glob(os.path.join('./demo_output/climatology-NGCM/', '*.json')))
for json_file in json_list_test_NGCM:
    print(json_file.split('/')[-1])
# Out:
# psl_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# ta-200_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# ta-500_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# ta-850_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# ua-200_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# ua-850_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# va-200_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# va-850_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# zg-200_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# zg-500_2.5x2.5_regrid2_metrics_climatology-NGCM.json
# zg-850_2.5x2.5_regrid2_metrics_climatology-NGCM.json

# %%
test_case1 = Metrics(json_list_test_NGCM)
test_case2 = Metrics(json_list_test)
test_case3 = Metrics(json_list_test_NGCM_evap)
combined = test_case1.merge(test_case2)
combined = combined.merge(test_case3)
combined = combined.merge(library)

# %%
library.df_dict['rms_xyt']['ann']['global']
# Out:
#                 model       run                   model_run       pr   ta-200  \
# 0          ACCESS-CM2  r1i1p1f1         ACCESS-CM2_r1i1p1f1  1.63400  2.48553
# 1       ACCESS-ESM1-5  r1i1p1f1      ACCESS-ESM1-5_r1i1p1f1  1.61329  2.09618
# 2         BCC-CSM2-MR  r1i1p1f1        BCC-CSM2-MR_r1i1p1f1  1.50727  2.37068
# 3         CAMS-CSM1-0  r1i1p1f1        CAMS-CSM1-0_r1i1p1f1  1.79018  3.34686
# 4             CanESM5  r1i1p1f1            CanESM5_r1i1p1f1  1.56014  2.69522
# 5          CAS-ESM2-0  r1i1p1f1         CAS-ESM2-0_r1i1p1f1  1.53640  4.20418
# 6               CESM2  r1i1p1f1              CESM2_r1i1p1f1  3.60910  1.99736
# 7           CESM2-FV2  r1i1p1f1          CESM2-FV2_r1i1p1f1  1.40967  2.68305
# 8         CESM2-WACCM  r1i1p1f1        CESM2-WACCM_r1i1p1f1  1.30180  1.90193
# 9     CESM2-WACCM-FV2  r1i1p1f1    CESM2-WACCM-FV2_r1i1p1f1  1.38749  2.66221
# 10              CIESM  r1i1p1f1              CIESM_r1i1p1f1  3.60533  3.20487
# 11       CMCC-CM2-HR4  r1i1p1f1       CMCC-CM2-HR4_r1i1p1f1  1.47838  3.09939
# 12       CMCC-CM2-SR5  r1i1p1f1       CMCC-CM2-SR5_r1i1p1f1  1.39071  3.47946
# 13         CNRM-CM6-1  r1i1p1f2         CNRM-CM6-1_r1i1p1f2  1.47220  4.50403
# 14      CNRM-CM6-1-HR  r1i1p1f2      CNRM-CM6-1-HR_r1i1p1f2  1.44690  4.36315
# 15        CNRM-ESM2-1  r1i1p1f2        CNRM-ESM2-1_r1i1p1f2  1.46083  4.56549
# 16           E3SM-1-0  r1i1p1f1           E3SM-1-0_r1i1p1f1  1.27361  2.08443
# 17           E3SM-2-0  r1i1p1f1           E3SM-2-0_r1i1p1f1  1.23534  2.35545
# 18     E3SM-2-0-NARRM  r1i1p1f1     E3SM-2-0-NARRM_r1i1p1f1  1.21333  2.28795
# 19           E3SM-2-1  r1i1p1f1           E3SM-2-1_r1i1p1f1  1.23799  2.35748
# 20          EC-Earth3  r1i1p1f1          EC-Earth3_r1i1p1f1  1.05981  1.63836
# 21  EC-Earth3-AerChem  r1i1p1f1  EC-Earth3-AerChem_r1i1p1f1  1.09647  1.82957
# 22       EC-Earth3-CC  r1i1p1f1       EC-Earth3-CC_r1i1p1f1  1.06489  1.62055
# 23      EC-Earth3-Veg  r1i1p1f1      EC-Earth3-Veg_r1i1p1f1  1.06010  1.64779
# 24   EC-Earth3-Veg-LR  r1i1p1f1   EC-Earth3-Veg-LR_r1i1p1f1  1.09703  1.74100
# 25        FGOALS-f3-L  r1i1p1f1        FGOALS-f3-L_r1i1p1f1  1.78762  1.90822
# 26          FGOALS-g3  r1i1p1f1          FGOALS-g3_r1i1p1f1  1.74804  5.21769
# 27        FIO-ESM-2-0  r1i1p1f1        FIO-ESM-2-0_r1i1p1f1  1.40841  3.59015
# 28           GFDL-CM4  r1i1p1f1           GFDL-CM4_r1i1p1f1  1.22659  1.29207
# 29        GISS-E2-1-G  r1i1p1f1        GISS-E2-1-G_r1i1p1f1  1.85545  2.99091
# 30        GISS-E2-2-G  r1i1p3f1        GISS-E2-2-G_r1i1p3f1  1.57537  2.80764
# 31    HadGEM3-GC31-LL  r1i1p1f3    HadGEM3-GC31-LL_r1i1p1f3  1.60301  2.42482
# 32    HadGEM3-GC31-MM  r1i1p1f3    HadGEM3-GC31-MM_r1i1p1f3  1.46918  1.70745
# 33          INM-CM4-8  r1i1p1f1          INM-CM4-8_r1i1p1f1  1.51010  3.73867
# 34          INM-CM5-0  r1i1p1f1          INM-CM5-0_r1i1p1f1  1.57964  3.10942
# 35       IPSL-CM6A-LR  r1i1p1f1       IPSL-CM6A-LR_r1i1p1f1  1.61846  3.09808
# 36      IPSL-CM6A-MR1  r1i1p1f1      IPSL-CM6A-MR1_r1i1p1f1  1.64623  2.01721
# 37         KACE-1-0-G  r1i1p1f1         KACE-1-0-G_r1i1p1f1  1.53878  2.60652
# 38          KIOST-ESM  r1i1p1f1          KIOST-ESM_r1i1p1f1  1.53172  2.46597
# 39         MIROC-ES2L  r1i1p1f2         MIROC-ES2L_r1i1p1f2  1.76353  4.97532
# 40             MIROC6  r1i1p1f1             MIROC6_r1i1p1f1  1.84058  2.88442
# 41    MPI-ESM-1-2-HAM  r1i1p1f1    MPI-ESM-1-2-HAM_r1i1p1f1  1.94998  4.48948
# 42      MPI-ESM1-2-HR  r1i1p1f1      MPI-ESM1-2-HR_r1i1p1f1  1.50326  1.74678
# 43      MPI-ESM1-2-LR  r1i1p1f1      MPI-ESM1-2-LR_r1i1p1f1  1.63032  3.15185
# 44         MRI-ESM2-0  r1i1p1f1         MRI-ESM2-0_r1i1p1f1  1.25950  1.42814
# 45              NESM3  r1i1p1f1              NESM3_r1i1p1f1  1.86937  3.13588
# 46            NorCPM1  r1i1p1f1            NorCPM1_r1i1p1f1  1.58108  3.46942
# 47         NorESM2-LM  r1i1p1f1         NorESM2-LM_r1i1p1f1  1.44395  2.78436
# 48        SAM0-UNICON  r1i1p1f1        SAM0-UNICON_r1i1p1f1  1.33199  3.33872
# 49            TaiESM1  r1i1p1f1            TaiESM1_r1i1p1f1  1.37088  2.85903
# 50        UKESM1-0-LL  r1i1p1f2        UKESM1-0-LL_r1i1p1f2  1.59858  2.29013
# 51        UKESM1-1-LL  r1i1p1f2        UKESM1-1-LL_r1i1p1f2  1.58100  2.24459
#
#       ta-850   ua-200   ua-850   va-200    va-850    zg-500      psl
# 0   0.934347  3.54905  1.40264  1.79972  0.797086   17.6982  245.875
# 1   1.049410  3.98740  1.69593  1.98000  0.903500   26.7045  273.072
# 2   1.594380  3.33018  1.72431  1.66098  1.057420   22.1929  293.772
# 3   1.812810  5.41139  1.59085  2.15987  0.915529   33.6535  212.197
# 4   1.513590  3.65926  1.61051  1.75007  0.996951   24.6992  260.997
# 5   2.049650  4.13246  1.88585  2.26326  1.041290   31.2176  261.372
# 6   1.446080  3.77874  1.75357  1.80049  0.836053   26.3263  254.582
# 7   1.882320  4.21697  2.24302  1.93704  0.992991   27.3720  265.516
# 8   1.459650  3.85950  1.77828  1.80125  0.836665   26.5339  249.846
# 9   1.894040  3.93503  2.15577  1.88512  0.977351   25.5131  248.425
# 10  1.221760  3.30896  1.42897  1.60655  0.787801   39.6447  216.753
# 11  1.576220  3.34199  1.91310  1.85033  1.118290   29.5040  302.732
# 12  1.551100  2.95118  1.44940  1.57192  0.847116   25.6923  241.553
# 13  1.211610  3.99880  1.61081  2.07183  0.890470   35.4214  235.330
# 14  1.047710  3.95322  1.69288  2.04932  0.870823   36.5307  253.050
# 15  1.199990  4.02386  1.61909  2.05502  0.864947   36.5376  243.593
# 16  1.213040  2.89881  1.71995  1.61571  0.888599   25.1220  322.711
# 17  1.137060  3.38051  1.61173  1.76214  0.873366   24.9738  303.622
# 18  1.103810  3.25052  1.55537  1.69233  0.851083   23.9542  295.266
# 19  1.105320  3.28963  1.58589  1.70607  0.846817   23.8856  289.374
# 20  0.894096  2.45391  1.04222  1.29082  0.595881   16.0405  126.577
# 21  0.894689  2.47936  1.02747  1.31467  0.583912   17.1280  120.740
# 22  0.900923  2.43264  1.03989  1.27739  0.589080   15.5223  120.710
# 23  0.882387  2.37289  1.00441  1.24952  0.586599   15.2695  115.780
# 24  0.908644  2.71185  1.12349  1.39325  0.654051   18.1597  135.603
# 25  1.010140  4.31659  1.91821  1.97277  1.010410   28.5243  332.487
# 26  1.225640  3.82452  1.85164  1.94979  0.949910   27.1756  302.625
# 27  1.639700  3.03174  1.45965  1.58661  0.868505   27.8014  220.482
# 28  0.755857  2.40744  1.23711  1.50098  0.744303   18.2208  251.390
# 29  1.157130  5.77010  1.83862  2.52777  1.035070   36.5926  261.115
# 30  1.141940  4.33499  1.68911  2.06168  0.998352   52.6587  260.236
# 31  0.908411  3.43661  1.33195  1.73898  0.762818   17.2368  243.804
# 32  0.815613  3.02125  1.15375  1.50843  0.629827   17.4217  222.042
# 33  2.416850  4.27789  1.92045  2.00053  1.195390   31.9069  253.829
# 34  2.360230  4.14630  1.77065  1.93650  1.194430   29.3373  237.009
# 35  1.830130  3.77905  1.52424  1.81516  0.902124   44.3809  263.191
# 36  1.836400  3.45439  1.43795  1.70514  0.824134   42.3185  261.107
# 37  1.325540  3.51861  1.46449  1.73513  0.842258   19.8495  256.030
# 38  3.317340  3.73809  2.13280  1.93653  1.118950  224.0020  339.872
# 39  1.386160  4.24451  1.96398  2.16577  1.029850   34.8310  386.427
# 40  1.290920  3.49157  1.55409  1.84849  0.965354   24.1164  362.341
# 41  1.152510  4.13247  1.49478  2.02286  0.941228   21.0632  227.606
# 42  1.032970  2.91785  1.27012  1.63138  0.778488   24.5848  188.418
# 43  1.163800  3.76030  1.45641  1.77630  0.887489   25.5165  217.779
# 44  0.845132  2.84129  1.26305  1.44605  0.732779   21.2045  197.333
# 45  1.247250  6.88381  1.67613  2.64990  1.104780   31.2295  233.653
# 46  1.640270  3.86046  2.42876  2.05842  1.281400   31.3164  300.747
# 47  2.133880  4.26527  1.97625  2.06856  1.092080   30.8203  283.832
# 48  0.880763  3.31494  1.48369  1.90347  0.844686   34.4431  220.267
# 49  1.440670  2.80983  1.46537  1.53040  0.828642   24.5701  214.164
# 50  0.966141  3.55965  1.38094  1.72561  0.777613   17.8547  248.765
# 51  0.923273  3.47772  1.39092  1.70673  0.781458   18.3940  251.056

# %%
df_all = library.df_dict['rms_xyt']['ann']['global']

model_labels = list(df_all['model'])
model_names = model_labels
metric_names = ['pr', 'psl', 'ta-850', 'ta-200', 'va-850', 'va-200', 'zg-500']
data = df_all[metric_names].to_numpy()
model_highlights = None
print('data.shape:', data.shape)
print('len(model_names): ', len(model_labels))
# Out:
# data.shape: (52, 7)
# len(model_names):  52

# %%
vertical_center = "median"
fig, ax = parallel_coordinate_plot(data, metric_names, model_names,
                                   title='Mean Climate rms_xyt',
                                   figsize=(21, 7),
                                   colormap='tab20',
                                   show_boxplot=False,
                                   show_violin=True,
                                   violin_colors=("lightgrey", "pink"),
                                   xtick_labelsize=10,
                                   logo_rect=[0.8, 0.8, 0.15, 0.15],
                                   comparing_models=model_highlights,
                                   vertical_center=vertical_center,
                                   vertical_center_line=True
                                  )

ax.set_xticklabels(metric_names, rotation=30, va='top', ha="right")
# Out:
# [Text(0, 0, 'pr'),
#  Text(1, 0, 'psl'),
#  Text(2, 0, 'ta-850'),
#  Text(3, 0, 'ta-200'),
#  Text(4, 0, 'va-850'),
#  Text(5, 0, 'va-200'),
#  Text(6, 0, 'zg-500')]

# %%
df_all = combined.df_dict['rms_xyt']['ann']['global']
df_all.loc[0, 'model'] = 'NeuralGCM'
df_all = df_all[['model', 'pr', 'ta-850', 'ta-200', 'ua-850', 'ua-200', 'va-850', 'va-200', 'psl', 'zg-500', ]]
model_labels = list(df_all['model'])
model_names = model_labels
metric_names = ['pr', 'ta-850', 'ta-200', 'ua-850', 'ua-200', 'va-850', 'va-200', 'psl', 'zg-500', ]
data = df_all[metric_names].to_numpy()
model_highlights = None
print('data.shape:', data.shape)
print('len(model_names): ', len(model_labels))
# Out:
# data.shape: (55, 9)
# len(model_names):  55

# %%
vertical_center = "median"
model_highlights = ['NeuralGCM', 'ACE2', 'NeuralGCM-evap']
fig, ax = parallel_coordinate_plot(data, metric_names, model_names,
                                   models_to_highlight=model_highlights,
                                   models_to_highlight_colors=['blue', 'red', 'green'],
                                   title='Mean Climate ANN rms_xyt',
                                   figsize=(18, 6),
                                   colormap='tab20',
                                   show_boxplot=False,
                                   show_violin=True,
                                   violin_colors=("lightgrey", "pink"),
                                   xtick_labelsize=12,
                                   logo_rect=[0.8, 0.8, 0.15, 0.15],
                                   comparing_models=model_highlights,
                                   vertical_center=vertical_center,
                                   vertical_center_line=True,
                                   identify_all_models=False,
                                   models_to_highlight_by_line=False, 
                                   # models_to_highlight_labels=None, 
                                   models_to_highlight_markers=['s', 'o', '^', '*'],
                                  )

ax.set_xticklabels(metric_names, rotation=30, va='top', ha="right")
plt.savefig('Figs/mean-climate-parallel.png', dpi=120, bbox_inches='tight')
